# %% [markdown]
# <a href="https://colab.research.google.com/github/aaubs/ASE-Exam2026/blob/main/ASE_eksamen2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Studienummer:**

# %% [markdown]
# Dette er en colab fil, som du kan bruge til eksamen i anvendt statistik på HA Erhvervsøkonomi på 2. semester, 2026. Husk at gemme en lokal kopi, gem filen undervejs, og vedhæft den som bilag (.ipynb) til din besvarelse.
# HUSK: Evaluering og karaktergivning gives udelukkende på baggrund af hoved-dokument. Kopier dine visualiseringer over i hoveddokument efter behov.
#
# Held og lykke.

# %%
# Importer nødvendige pakker (gjort for jer)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Sæt Plot-stil (frivilligt, men anbefalet)

# %%
# Indlæs data
df = pd.read_csv('https://raw.githubusercontent.com/aaubs/ASE-Exam2026/refs/heads/main/data_eksamen26.csv')
